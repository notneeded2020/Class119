# %% [markdown]
# <a href="https://colab.research.google.com/github/notneeded2020/Class119/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
file_to_load = files.upload()
# Out:
#      <input type="file" id="files-528a2f20-6387-4295-87dc-60b6ce99d997" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-528a2f20-6387-4295-87dc-60b6ce99d997">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving diabetes.csv to diabetes.csv

# %%
import pandas as pd
import csv 

col_names = ["pregnant","glucose","bp","skin","insulin","bmi","pedigree","age","label"]

df = pd.read_csv("diabetes.csv", names = col_names).iloc[1:]
print(df.head())
# Out:
#   pregnant glucose  bp skin insulin   bmi pedigree age label
# 1        6     148  72   35       0  33.6    0.627  50     1
# 2        1      85  66   29       0  26.6    0.351  31     0
# 3        8     183  64    0       0  23.3    0.672  32     1
# 4        1      89  66   23      94  28.1    0.167  21     0
# 5        0     137  40   35     168  43.1    2.288  33     1

# %%
features = ["pregnant","glucose","bp","skin","insulin","bmi","pedigree","age"]
X = df[features]
Y = df.label

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

X_train,X_test,Y_train, Y_test = train_test_split(X,Y,test_size=0.3,random_state=1)
clf = DecisionTreeClassifier(max_depth = 3)
clf = clf.fit(X_train,Y_train)
Y_pred = clf.predict(X_test)
print("accuracy: ",metrics.accuracy_score(Y_test,Y_pred))
# Out:
# accuracy:  0.7575757575757576

# %%
from sklearn.tree import export_graphviz
from IPython.display import Image 
import pydotplus
from six import StringIO

dot_data = StringIO()
export_graphviz(clf,out_file=dot_data,filled=True,rounded=True,special_characters=True,feature_names = features,class_names = ["0","1"])
print(dot_data.getvalue())
# Out:
# digraph Tree {
# node [shape=box, style="filled, rounded", color="black", fontname="helvetica"] ;
# edge [fontname="helvetica"] ;
# 0 [label=<glucose &le; 129.5<br/>gini = 0.449<br/>samples = 537<br/>value = [354, 183]<br/>class = 0>, fillcolor="#f2c29f"] ;
# 1 [label=<bmi &le; 26.3<br/>gini = 0.329<br/>samples = 357<br/>value = [283, 74]<br/>class = 0>, fillcolor="#eca26d"] ;
# 0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;
# 2 [label=<bmi &le; 9.1<br/>gini = 0.06<br/>samples = 97<br/>value = [94, 3]<br/>class = 0>, fillcolor="#e6853f"] ;
# 1 -> 2 ;
# 3 [label=<gini = 0.444<br/>samples = 6<br/>value = [4, 2]<br/>class = 0>, fillcolor="#f2c09c"] ;
# 2 -> 3 ;
# 4 [label=<gini = 0.022<br/>samples = 91<br/>value = [90, 1]<br/>class = 0>, fillcolor="#e5823b"] ;
# 2 -> 4 ;
# 5 [label=<age &le; 27.5<br/>gini = 0.397<br/>samples = 260<br/>value = [189, 71]<br/>class = 0>, fillcolor="#efb083"] ;
# 1 -> 5 ;
# ...

# %%
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
graph.write_png("Diabetes.png")
Image(graph.create_png())
